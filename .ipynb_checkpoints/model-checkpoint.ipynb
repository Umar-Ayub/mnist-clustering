# %%
import keras
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from keras.preprocessing.image import ImageDataGenerator
import scipy.ndimage
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

X_train_upsampled = np.zeros(shape=(X_train.shape[0], 56, 56, 1))

i = 0
for img in X_train:
    a = scipy.ndimage.zoom(img, (2,2,1), order=0)
    X_train_upsampled[i] = a
    i += 1
    
print('Resampled by a factor of 2 with nearest interpolation:')
#print(scipy.ndimage.zoom(X_train, 2, order=0))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-b6b86fc6010e> in <module>()
#       3 X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
#       4
# ----> 5 X_train_upsampled = np.zeros(shape=(X_train.shape[0], 56, 56, 1))
#       6
#       7 i = 0
#
# MemoryError:

# %%
epochs=100

train_datagen = ImageDataGenerator(rotation_range=8, 
                                   width_shift_range=0.08,
                                   shear_range=0.3,
                                   height_shift_range=0.08,
                                   zoom_range=0.08)

test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow(X_train_upsampled, 
                                     y_train, 
                                     batch_size=32)

test_generator = test_datagen.flow(X_test,
                                   y_test, 
                                   batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-764e9268c1ce> in <module>()
#      11 train_generator = train_datagen.flow(X_train_upsampled,
#      12                                      y_train,
# ---> 13                                      batch_size=32)
#      14
#      15 test_generator = test_datagen.flow(X_test,
#
# /home/andrew_deew/anaconda3/lib/python3.5/site-packages/keras_preprocessing/image.py in flow(self, x, y, batch_size, shuffle, sample_weight, seed, save_to_dir, save_prefix, save_format, subset)
#     835             save_prefix=save_prefix,
#     836             save_format=save_format,
# --> 837             subset=subset)
#     838
#     839     def flow_from_directory(self, directory,
#
# /home/andrew_deew/anaconda3/lib/python3.5/site-packages/keras_preprocessing/image.py in __init__(self, x, y, image_data_generator, batch_size, shuffle, sample_weight, seed, data_format, save_to_dir, save_prefix, save_format, subset)
#    1364                              'should have the same length. '
#    1365                              'Found: x.shape = %s, y.shape = %s' %
# -> 1366                              (np.asarray(x).shape, np.asarray(y).shape))
#    1367         if sample_weight is not None and len(x) != len(sample_weight):
#    1368             raise ValueError('`x` (images tensor) and `sample_weight` '
#
# ValueError: `x` (images tensor) and `y` (labels) should have the same length. Found: x.shape = (56, 56, 1), y.shape = (60000,)

# %%
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
    
data_batch, labels_batch = next(train_generator)

def plots(ims, figsize=(12,6), rows=2, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if ims.shape[-1] != 3 :
            ims = ims.transpose(0,2,3,1)
    
    f = plt.figure(figsize=figsize)
    
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows+1
    for i in range(len(ims)):
        sp = f.add_subplot(rows,cols,i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i].reshape(28,28), interpolation = None if interp else 'none', cmap='gray')
        
plots(data_batch, titles = labels_batch)
# Out:
# data batch shape: (32, 28, 28, 1)
# labels batch shape: (32,)

# %% [markdown]
# # Load VGG Model

# %%
from keras.applications import VGG16
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(28, 28, 3))

conv_base.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-ba929bdb5196> in <module>()
#       2 conv_base = VGG16(weights='imagenet',
#       3                   include_top=False,
# ----> 4                   input_shape=(28, 28, 3))
#       5
#       6 conv_base.summary()
#
# /home/andrew_deew/anaconda3/lib/python3.5/site-packages/keras_applications/vgg16.py in VGG16(include_top, weights, input_tensor, input_shape, pooling, classes)
#     101                                       data_format=backend.image_data_format(),
#     102                                       require_flatten=include_top,
# --> 103                                       weights=weights)
#     104
#     105     if input_tensor is None:
#
# /home/andrew_deew/anaconda3/lib/python3.5/site-packages/keras_applications/imagenet_utils.py in _obtain_input_shape(input_shape, default_size, min_size, data_format, require_flatten, weights)
#     314                                      str(min_size) + 'x' + str(min_size) +
#     315                                      '; got `input_shape=' +
# --> 316                                      str(input_shape) + '`')
#     317     else:
#     318         if require_flatten:
#
# ValueError: Input size must be at least 48x48; got `input_shape=(28, 28, 3)`

# %%
def extract_features(sample_count, generator):
    features = np.zeros(shape=(sample_count, 7, 7, 512))
    labels = np.zeros(shape=(sample_count, 1))
    
    i = 0   
    for inputs_batch, labels_batch in generator:
        features_batch = conv_base.predict(inputs_batch)
        features[i*batch_size : (i+1)*batch_size] = features_batch
        labels[i*batch_size : (i+1)*batch_size] = labels_batch
        i += 1
        if i*batch_size >= sample_count:
            break
    return features, labels
